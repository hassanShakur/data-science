# %% [markdown]
# # Matplotlib
#
# We'll take a look at:
#
# * Line
# * Scatter
# * Bar
# * Histogram
# * Subplots

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %% [markdown]
# ## Recommended way of creating figures
#
# The recommended is using the API OOP method when creating `figures`. Here the figure is the general structure while the `subplots` are axes in the figure and lines.

# %% [markdown]
# ### Line Graphs

# %%
# Initialize the instance
fig, ax = plt.subplots(figsize=(5, 5))

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Actual plot
ax.plot(x, y)

# Set axes and title
ax.set(title='A Linear Function',
       xlabel='x-axis',
       ylabel='y-axis'
      )

# Exporting
# fig.savefig('path/to/save')
# Out:
# [Text(0.5, 1.0, 'A Linear Function'),
#  Text(0.5, 0, 'x-axis'),
#  Text(0, 0.5, 'y-axis')]

# %%
# Create linearly spaced nums btwn 2 vals
arr = np.linspace(0, 10, 50)
arr[:10]
# Out:
# array([0.        , 0.20408163, 0.40816327, 0.6122449 , 0.81632653,
#        1.02040816, 1.2244898 , 1.42857143, 1.63265306, 1.83673469])

# %%
# Plot
fig, ax = plt.subplots()
ax.plot(arr, arr**2)

# %% [markdown]
# ### Scatter Plots

# %%
# Scatter
fig, ax = plt.subplots()
ax.scatter(arr, np.exp(arr))

# %%
# Sin wave
fig, ax = plt.subplots()
ax.scatter(arr, np.sin(arr))

# %%
books = {
    'Educational': 22,
    'Romance': 43,
    'Explorative': 10,
    'Poetic': 30,
    'Perception': 7
}

# %% [markdown]
# ### Bar Graphs

# %%
# Bar
fig, ax = plt.subplots()
ax.bar(books.keys(), books.values())

ax.set(
    title = 'My Books',
    ylabel = 'Count'
)
# Out:
# [Text(0.5, 1.0, 'My Books'), Text(0, 0.5, 'Count')]

# %%
# Horizontal bar - Use Lists
fig, ax = plt.subplots()
ax.barh(list(books.keys()), list(books.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
# Create a normal Gauss probability distribution data
pdist = np.random.randn(1000)
pdist[:10]
# Out:
# array([-1.42916034,  0.09919278, -0.22815622, -0.44502961, -0.1494173 ,
#        -0.38523957,  0.82098136,  1.52285832, -2.02347739,  0.37161582])

# %%
# Histogram
fig, ax = plt.subplots()
ax.hist(pdist)
# Out:
# (array([  7.,  24.,  83., 145., 242., 234., 159.,  71.,  26.,   9.]),
#  array([-2.89083518, -2.30547059, -1.72010601, -1.13474143, -0.54937685,
#          0.03598773,  0.62135231,  1.20671689,  1.79208147,  2.37744605,
#          2.96281063]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Subplots

# %% [markdown]
# #### Version 1

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(10, 10)
)

ax1.plot(arr)
ax2.scatter(np.random.random(40), np.random.random(40))
ax3.hist(pdist)
ax4.bar(books.keys(), books.values())
# Out:
# <BarContainer object of 5 artists>
